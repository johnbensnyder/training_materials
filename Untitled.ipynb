# %% [markdown]
# # Getting some data

# %%
# Let's say we want to keep several years of GSS data in different tables.
import requests, zipfile, io
import pandas as pd
years = [2010, 2012, 2014, 2016]
gss_dfs = {}
for year in years:
    r = requests.get('http://gss.norc.org/documents/stata/' + str(year) +'_stata.zip')
    z = zipfile.ZipFile(io.BytesIO(r.content))
    z.extractall()
    gss_dfs[year] = pd.read_stata('GSS' + str(year) + '.DTA', convert_categoricals=False)

# %%
# Create sqlite database

import sqlite3

conn = sqlite3.connect('GSS.db')
conn.text_factory = str

# %%
c = conn.cursor()

# %%
gss_dfs[2016].to_sql("year_2016", conn, if_exists="replace")

# %%
res = c.execute("SELECT name FROM sqlite_master WHERE type='table';")

# %%
res

# %%
res.fetchall()
# Out:
# [('year_2016',)]

# %%
for year in years:
    gss_dfs[year].to_sql('year_' + str(year), conn, if_exists="replace")

# %%
c.execute("PRAGMA table_info(year_2016)").fetchall()
# Out:
# [(0, 'index', 'INTEGER', 0, None, 0),
#  (1, 'mar1', 'REAL', 0, None, 0),
#  (2, 'mar2', 'REAL', 0, None, 0),
#  (3, 'mar3', 'REAL', 0, None, 0),
#  (4, 'mar4', 'REAL', 0, None, 0),
#  (5, 'mar5', 'REAL', 0, None, 0),
#  (6, 'mar6', 'REAL', 0, None, 0),
#  (7, 'mar7', 'REAL', 0, None, 0),
#  (8, 'mar8', 'REAL', 0, None, 0),
#  (9, 'mar9', 'REAL', 0, None, 0),
#  (10, 'mar10', 'REAL', 0, None, 0),
#  (11, 'mar11', 'REAL', 0, None, 0),
#  (12, 'mar12', 'REAL', 0, None, 0),
#  (13, 'mar13', 'REAL', 0, None, 0),
#  (14, 'mar14', 'REAL', 0, None, 0),
#  (15, 'abany', 'REAL', 0, None, 0),
#  (16, 'abdefect', 'REAL', 0, None, 0),
#  (17, 'abhlth', 'REAL', 0, None, 0),
#  (18, 'abnomore', 'REAL', 0, None, 0),
#  (19, 'abpoor', 'REAL', 0, None, 0),
#  (20, 'abrape', 'REAL', 0, None, 0),
#  (21, 'absingle', 'REAL', 0, None, 0),
#  (22, 'acqntsex', 'REAL', 0, None, 0),
#  (23, 'adforjob', 'REAL', 0, None, 0),
#  (24, 'adults', 'REAL', 0, None, 0),
#  (25, 'advfront', 'REAL', 0, None, 0),
#  (26, 'advsched', 'REAL', 0, None, 0),
#  (27, 'affrmact', 'REAL', 0, None, 0),
#  (28, 'age', 'REAL', 0, None, 0),
#  (29, 'age3', 'REAL', 0, None, 0),
#  (30, 'aged', 'REAL', 0, None, 0),
#  (31, 'agedchld', 'REAL', 0, None, 0),
#  (32, 'agedpar', 'REAL', 0, None, 0),
#  (33, 'agekdbrn', 'REAL', 0, None, 0),
#  (34, 'aidcol', 'REAL', 0, None, 0),
#  (35, 'aidhouse', 'REAL', 0, None, 0),
#  (36, 'aidindus', 'REAL', 0, None, 0),
#  (37, 'aidold', 'REAL', 0, None, 0),
#  (38, 'aidunemp', 'REAL', 0, None, 0),
#  (39, 'appemps', 'REAL', 0, None, 0),
#  (40, 'artatt', 'REAL', 0, None, 0),
#  (41, 'artatt1', 'REAL', 0, None, 0),
#  (42, 'artatt2', 'REAL', 0, None, 0),
#  (43, 'artatt3', 'REAL', 0, None, 0),
#  (44, 'artatt4', 'REAL', 0, None, 0),
#  (45, 'artatt5', 'REAL', 0, None, 0),
#  (46, 'artcost', 'REAL', 0, None, 0),
#  (47, 'artexbt', 'REAL', 0, None, 0),
#  (48, 'artfree', 'REAL', 0, None, 0),
#  (49, 'artgst', 'REAL', 0, None, 0),
#  (50, 'artint', 'REAL', 0, None, 0),
#  (51, 'artloc', 'REAL', 0, None, 0),
#  (52, 'artmostoth', 'REAL', 0, None, 0),
#  (53, 'artothr', 'REAL', 0, None, 0),
#  (54, 'arttime', 'REAL', 0, None, 0),
#  (55, 'arttrvl', 'REAL', 0, None, 0),
#  (56, 'artwhy1', 'REAL', 0, None, 0),
#  (57, 'artwhy2', 'REAL', 0, None, 0),
#  (58, 'artwhy3', 'REAL', 0, None, 0),
#  (59, 'artwhy4', 'REAL', 0, None, 0),
#  (60, 'artwhy5', 'REAL', 0, None, 0),
#  (61, 'artwhy6', 'REAL', 0, None, 0),
#  (62, 'artwhy7', 'REAL', 0, None, 0),
#  (63, 'artwhy8', 'REAL', 0, None, 0),
#  (64, 'artwhy9', 'REAL', 0, None, 0),
#  (65, 'askhelp', 'REAL', 0, None, 0),
#  (66, 'astrolgy', 'REAL', 0, None, 0),
#  (67, 'astrosci', 'REAL', 0, None, 0),
#  (68, 'attend', 'REAL', 0, None, 0),
#  (69, 'away1', 'REAL', 0, None, 0),
#  (70, 'away11', 'REAL', 0, None, 0),
#  (71, 'away13', 'REAL', 0, None, 0),
#  (72, 'away2', 'REAL', 0, None, 0),
#  (73, 'away3', 'REAL', 0, None, 0),
#  (74, 'away4', 'REAL', 0, None, 0),
#  (75, 'away5', 'REAL', 0, None, 0),
#  (76, 'away6', 'REAL', 0, None, 0),
#  (77, 'away7', 'REAL', 0, None, 0),
#  (78, 'babies', 'REAL', 0, None, 0),
#  (79, 'ballot', 'INTEGER', 0, None, 0),
#  (80, 'balneg', 'REAL', 0, None, 0),
#  (81, 'balpos', 'REAL', 0, None, 0),
#  (82, 'betrlang', 'REAL', 0, None, 0),
#  (83, 'bible', 'REAL', 0, None, 0),
#  (84, 'bigbang', 'REAL', 0, None, 0),
#  (85, 'bigbang1', 'REAL', 0, None, 0),
#  (86, 'bigbang2', 'REAL', 0, None, 0),
#  (87, 'bored', 'REAL', 0, None, 0),
#  (88, 'born', 'REAL', 0, None, 0),
#  (89, 'bossemps', 'REAL', 0, None, 0),
#  (90, 'boyorgrl', 'REAL', 0, None, 0),
#  (91, 'bribe', 'REAL', 0, None, 0),
#  (92, 'brlawfl', 'REAL', 0, None, 0),
#  (93, 'brnotax', 'REAL', 0, None, 0),
#  (94, 'cappun', 'REAL', 0, None, 0),
#  (95, 'cctv', 'REAL', 0, None, 0),
#  (96, 'cesd1', 'REAL', 0, None, 0),
#  (97, 'cesd2', 'REAL', 0, None, 0),
#  (98, 'cesd3', 'REAL', 0, None, 0),
#  (99, 'cesd4', 'REAL', 0, None, 0),
#  (100, 'cesd5', 'REAL', 0, None, 0),
#  (101, 'chemgen', 'REAL', 0, None, 0),
#  (102, 'childs', 'REAL', 0, None, 0),
#  (103, 'chldidel', 'REAL', 0, None, 0),
#  (104, 'chngewrk', 'REAL', 0, None, 0),
#  (105, 'class', 'REAL', 0, None, 0),
#  (106, 'closeblk', 'REAL', 0, None, 0),
#  (107, 'closewht', 'REAL', 0, None, 0),
#  (108, 'clssmtes', 'REAL', 0, None, 0),
#  (109, 'codeg', 'REAL', 0, None, 0),
#  (110, 'coden', 'REAL', 0, None, 0),
#  (111, 'codipged', 'REAL', 0, None, 0),
#  (112, 'coeduc', 'REAL', 0, None, 0),
#  (113, 'coevwork', 'REAL', 0, None, 0),
#  (114, 'cofund', 'REAL', 0, None, 0),
#  (115, 'cohort', 'REAL', 0, None, 0),
#  (116, 'cohrs1', 'REAL', 0, None, 0),
#  (117, 'cohrs2', 'REAL', 0, None, 0),
#  (118, 'coind10', 'REAL', 0, None, 0),
#  (119, 'coisco08', 'REAL', 0, None, 0),
#  (120, 'cojew', 'REAL', 0, None, 0),
#  (121, 'colath', 'REAL', 0, None, 0),
#  (122, 'colcom', 'REAL', 0, None, 0),
#  (123, 'coldeg1', 'REAL', 0, None, 0),
#  (124, 'colhomo', 'REAL', 0, None, 0),
#  (125, 'colmil', 'REAL', 0, None, 0),
#  (126, 'colmslm', 'REAL', 0, None, 0),
#  (127, 'colrac', 'REAL', 0, None, 0),
#  (128, 'colsci', 'REAL', 0, None, 0),
#  (129, 'colscinm', 'REAL', 0, None, 0),
#  (130, 'comprend', 'REAL', 0, None, 0),
#  (131, 'compuse', 'REAL', 0, None, 0),
#  (132, 'conarmy', 'REAL', 0, None, 0),
#  (133, 'conbus', 'REAL', 0, None, 0),
#  (134, 'conclerg', 'REAL', 0, None, 0),
#  (135, 'condom', 'REAL', 0, None, 0),
#  (136, 'condrift', 'REAL', 0, None, 0),
#  (137, 'coneduc', 'REAL', 0, None, 0),
#  (138, 'confed', 'REAL', 0, None, 0),
#  (139, 'confinan', 'REAL', 0, None, 0),
#  (140, 'coninc', 'REAL', 0, None, 0),
#  (141, 'conjudge', 'REAL', 0, None, 0),
#  (142, 'conlabor', 'REAL', 0, None, 0),
#  (143, 'conlegis', 'REAL', 0, None, 0),
#  (144, 'conmedic', 'REAL', 0, None, 0),
#  (145, 'conpress', 'REAL', 0, None, 0),
#  (146, 'conrinc', 'REAL', 0, None, 0),
#  (147, 'consci', 'REAL', 0, None, 0),
#  (148, 'consent', 'INTEGER', 0, None, 0),
#  (149, 'contv', 'REAL', 0, None, 0),
#  (150, 'coocc10', 'REAL', 0, None, 0),
#  (151, 'coop', 'REAL', 0, None, 0),
#  (152, 'coother', 'REAL', 0, None, 0),
#  (153, 'copres10', 'REAL', 0, None, 0),
#  (154, 'copres105plus', 'REAL', 0, None, 0),
#  (155, 'corel', 'REAL', 0, None, 0),
#  (156, 'corrupt1', 'REAL', 0, None, 0),
#  (157, 'corrupt2', 'REAL', 0, None, 0),
#  (158, 'cosei10', 'REAL', 0, None, 0),
#  (159, 'cosei10educ', 'REAL', 0, None, 0),
#  (160, 'cosei10inc', 'REAL', 0, None, 0),
#  (161, 'courts', 'REAL', 0, None, 0),
#  (162, 'cowrkers', 'REAL', 0, None, 0),
#  (163, 'cowrkslf', 'REAL', 0, None, 0),
#  (164, 'cowrksta', 'REAL', 0, None, 0),
#  (165, 'crack30', 'REAL', 0, None, 0),
#  (166, 'cutgovt', 'REAL', 0, None, 0),
#  (167, 'cuthours', 'REAL', 0, None, 0),
#  (168, 'dailywrk', 'REAL', 0, None, 0),
#  (169, 'dateintv', 'INTEGER', 0, None, 0),
#  (170, 'decidwrk', 'REAL', 0, None, 0),
#  (171, 'degree', 'REAL', 0, None, 0),
#  (172, 'denom', 'REAL', 0, None, 0),
#  (173, 'denom16', 'REAL', 0, None, 0),
#  (174, 'dipged', 'REAL', 0, None, 0),
#  (175, 'discaff', 'REAL', 0, None, 0),
#  (176, 'discaffm', 'REAL', 0, None, 0),
#  (177, 'discaffw', 'REAL', 0, None, 0),
#  (178, 'discwk5', 'REAL', 0, None, 0),
#  (179, 'divlaw', 'REAL', 0, None, 0),
#  (180, 'divorce', 'REAL', 0, None, 0),
#  (181, 'dwelling', 'REAL', 0, None, 0),
#  (182, 'dwelown', 'REAL', 0, None, 0),
#  (183, 'earnrs', 'REAL', 0, None, 0),
#  (184, 'earthsun', 'REAL', 0, None, 0),
#  (185, 'econsup1', 'REAL', 0, None, 0),
#  (186, 'educ', 'REAL', 0, None, 0),
#  (187, 'electron', 'REAL', 0, None, 0),
#  (188, 'emailhr', 'REAL', 0, None, 0),
#  (189, 'emailmin', 'REAL', 0, None, 0),
#  (190, 'emonitor', 'REAL', 0, None, 0),
#  (191, 'equalize', 'REAL', 0, None, 0),
#  (192, 'eqwlth', 'REAL', 0, None, 0),
#  (193, 'eth1', 'REAL', 0, None, 0),
#  (194, 'eth2', 'REAL', 0, None, 0),
#  (195, 'eth3', 'REAL', 0, None, 0),
#  (196, 'ethnic', 'REAL', 0, None, 0),
#  (197, 'ethnum', 'REAL', 0, None, 0),
#  (198, 'evbrkdwn', 'REAL', 0, None, 0),
#  (199, 'evcrack', 'REAL', 0, None, 0),
#  (200, 'evidu', 'REAL', 0, None, 0),
#  (201, 'evjob', 'REAL', 0, None, 0),
#  (202, 'evolved', 'REAL', 0, None, 0),
#  (203, 'evolved2', 'REAL', 0, None, 0),
#  (204, 'evpaidsx', 'REAL', 0, None, 0),
#  (205, 'evstray', 'REAL', 0, None, 0),
#  (206, 'evwork', 'REAL', 0, None, 0),
#  (207, 'exjobsat', 'REAL', 0, None, 0),
#  (208, 'expdesgn', 'REAL', 0, None, 0),
#  (209, 'exptext', 'REAL', 0, None, 0),
#  (210, 'extraern', 'REAL', 0, None, 0),
#  (211, 'extrawrk', 'REAL', 0, None, 0),
#  (212, 'facebook', 'REAL', 0, None, 0),
#  (213, 'fair', 'REAL', 0, None, 0),
#  (214, 'famdif16', 'REAL', 0, None, 0),
#  (215, 'famgen', 'INTEGER', 0, None, 0),
#  (216, 'family16', 'REAL', 0, None, 0),
#  (217, 'famintjb', 'REAL', 0, None, 0),
#  (218, 'famorjob', 'REAL', 0, None, 0),
#  (219, 'fear', 'REAL', 0, None, 0),
#  (220, 'fechld', 'REAL', 0, None, 0),
#  (221, 'feelevel', 'REAL', 0, None, 0),
#  (222, 'feeused', 'REAL', 0, None, 0),
#  (223, 'fefam', 'REAL', 0, None, 0),
#  (224, 'fehire', 'REAL', 0, None, 0),
#  (225, 'fejobaff', 'REAL', 0, None, 0),
#  (226, 'fepol', 'REAL', 0, None, 0),
#  (227, 'fepresch', 'REAL', 0, None, 0),
#  (228, 'finalter', 'REAL', 0, None, 0),
#  (229, 'finrela', 'REAL', 0, None, 0),
#  (230, 'flexhrs1', 'REAL', 0, None, 0),
#  (231, 'flickr', 'REAL', 0, None, 0),
#  (232, 'form', 'INTEGER', 0, None, 0),
#  (233, 'formwt', 'INTEGER', 0, None, 0),
#  (234, 'frndsex', 'REAL', 0, None, 0),
#  (235, 'fucitzn', 'REAL', 0, None, 0),
#  (236, 'fund', 'REAL', 0, None, 0),
#  (237, 'fund16', 'REAL', 0, None, 0),
#  (238, 'gender1', 'INTEGER', 0, None, 0),
#  (239, 'gender10', 'REAL', 0, None, 0),
#  (240, 'gender11', 'REAL', 0, None, 0),
#  (241, 'gender12', 'REAL', 0, None, 0),
#  (242, 'gender13', 'REAL', 0, None, 0),
#  (243, 'gender14', 'REAL', 0, None, 0),
#  (244, 'gender2', 'REAL', 0, None, 0),
#  (245, 'gender3', 'REAL', 0, None, 0),
#  (246, 'gender4', 'REAL', 0, None, 0),
#  (247, 'gender5', 'REAL', 0, None, 0),
#  (248, 'gender6', 'REAL', 0, None, 0),
#  (249, 'gender7', 'REAL', 0, None, 0),
#  (250, 'gender8', 'REAL', 0, None, 0),
#  (251, 'gender9', 'REAL', 0, None, 0),
#  (252, 'gendereq', 'REAL', 0, None, 0),
#  (253, 'genegen', 'REAL', 0, None, 0),
#  (254, 'getahead', 'REAL', 0, None, 0),
#  (255, 'getjob', 'REAL', 0, None, 0),
#  (256, 'givinffor', 'REAL', 0, None, 0),
#  (257, 'givinfusa', 'REAL', 0, None, 0),
#  (258, 'god', 'REAL', 0, None, 0),
#  (259, 'goodlife', 'REAL', 0, None, 0),
#  (260, 'googlesn', 'REAL', 0, None, 0),
#  (261, 'govtinfo', 'REAL', 0, None, 0),
#  (262, 'granborn', 'REAL', 0, None, 0),
#  (263, 'grass', 'REAL', 0, None, 0),
#  (264, 'grnlaws', 'REAL', 0, None, 0),
#  (265, 'gunlaw', 'REAL', 0, None, 0),
#  (266, 'gvinflu1', 'REAL', 0, None, 0),
#  (267, 'gvinflu2', 'REAL', 0, None, 0),
#  (268, 'hapcohab', 'REAL', 0, None, 0),
#  (269, 'hapmar', 'REAL', 0, None, 0),
#  (270, 'happy', 'REAL', 0, None, 0),
#  (271, 'harass5', 'REAL', 0, None, 0),
#  (272, 'health', 'REAL', 0, None, 0),
#  (273, 'hefinfo', 'INTEGER', 0, None, 0),
#  (274, 'helpblk', 'REAL', 0, None, 0),
#  (275, 'helpful', 'REAL', 0, None, 0),
#  (276, 'helpnot', 'REAL', 0, None, 0),
#  (277, 'helporg1', 'REAL', 0, None, 0),
#  (278, 'helpoth', 'REAL', 0, None, 0),
#  (279, 'helppoor', 'REAL', 0, None, 0),
#  (280, 'helpsick', 'REAL', 0, None, 0),
#  (281, 'hhrace', 'REAL', 0, None, 0),
#  (282, 'hhtype', 'REAL', 0, None, 0),
#  (283, 'hhtype1', 'REAL', 0, None, 0),
#  (284, 'hiinc', 'REAL', 0, None, 0),
#  (285, 'hispanic', 'REAL', 0, None, 0),
#  (286, 'hivtest', 'REAL', 0, None, 0),
#  (287, 'hivtest1', 'REAL', 0, None, 0),
#  (288, 'hivtest2', 'REAL', 0, None, 0),
#  (289, 'hlphitec', 'REAL', 0, None, 0),
#  (290, 'hlpoths', 'REAL', 0, None, 0),
#  (291, 'hlpsoc', 'REAL', 0, None, 0),
#  (292, 'hlthcare', 'REAL', 0, None, 0),
#  (293, 'homosex', 'REAL', 0, None, 0),
#  (294, 'hompop', 'INTEGER', 0, None, 0),
#  (295, 'hope1', 'REAL', 0, None, 0),
#  (296, 'hope2', 'REAL', 0, None, 0),
#  (297, 'hope3', 'REAL', 0, None, 0),
#  (298, 'hope4', 'REAL', 0, None, 0),
#  (299, 'hope5', 'REAL', 0, None, 0),
#  (300, 'hope6', 'REAL', 0, None, 0),
#  (301, 'hotcore', 'REAL', 0, None, 0),
#  (302, 'hrs1', 'REAL', 0, None, 0),
#  (303, 'hrs2', 'REAL', 0, None, 0),
#  (304, 'hrsmoney', 'REAL', 0, None, 0),
#  (305, 'hsbio', 'REAL', 0, None, 0),
#  (306, 'hschem', 'REAL', 0, None, 0),
#  (307, 'hsmath', 'REAL', 0, None, 0),
#  (308, 'hsphys', 'REAL', 0, None, 0),
#  (309, 'huclean', 'REAL', 0, None, 0),
#  (310, 'hunt', 'REAL', 0, None, 0),
#  (311, 'hunt1', 'REAL', 0, None, 0),
#  (312, 'id', 'INTEGER', 0, None, 0),
#  (313, 'idu30', 'REAL', 0, None, 0),
#  (314, 'if12who', 'REAL', 0, None, 0),
#  (315, 'incom16', 'REAL', 0, None, 0),
#  (316, 'income', 'REAL', 0, None, 0),
#  (317, 'income16', 'REAL', 0, None, 0),
#  (318, 'indus10', 'REAL', 0, None, 0),
#  (319, 'indusgen', 'REAL', 0, None, 0),
#  (320, 'instagrm', 'REAL', 0, None, 0),
#  (321, 'intage', 'INTEGER', 0, None, 0),
#  (322, 'intecon', 'REAL', 0, None, 0),
#  (323, 'inteduc', 'REAL', 0, None, 0),
#  (324, 'intenvir', 'REAL', 0, None, 0),
#  (325, 'intethn', 'INTEGER', 0, None, 0),
#  (326, 'intfarm', 'REAL', 0, None, 0),
#  (327, 'inthisp', 'REAL', 0, None, 0),
#  (328, 'intid', 'INTEGER', 0, None, 0),
#  (329, 'intintl', 'REAL', 0, None, 0),
#  (330, 'intjob', 'REAL', 0, None, 0),
#  (331, 'intlblks', 'REAL', 0, None, 0),
#  (332, 'intlwhts', 'REAL', 0, None, 0),
#  (333, 'intmbile', 'REAL', 0, None, 0),
#  (334, 'intmed', 'REAL', 0, None, 0),
#  (335, 'intmil', 'REAL', 0, None, 0),
#  (336, 'intrace1', 'REAL', 0, None, 0),
#  (337, 'intrace2', 'REAL', 0, None, 0),
#  (338, 'intrace3', 'REAL', 0, None, 0),
#  (339, 'intrecnt', 'REAL', 0, None, 0),
#  (340, 'intsci', 'REAL', 0, None, 0),
#  (341, 'intsex', 'INTEGER', 0, None, 0),
#  (342, 'intspace', 'REAL', 0, None, 0),
#  (343, 'inttech', 'REAL', 0, None, 0),
#  (344, 'intuse', 'REAL', 0, None, 0),
#  (345, 'intwkdyh', 'REAL', 0, None, 0),
#  (346, 'intwkdym', 'REAL', 0, None, 0),
#  (347, 'intwkenh', 'REAL', 0, None, 0),
#  (348, 'intwkenm', 'REAL', 0, None, 0),
#  (349, 'intyrs', 'INTEGER', 0, None, 0),
#  (350, 'isco08', 'REAL', 0, None, 0),
#  (351, 'isco88', 'REAL', 0, None, 0),
#  (352, 'issp', 'INTEGER', 0, None, 0),
#  (353, 'jbendmo', 'REAL', 0, None, 0),
#  (354, 'jbendyr', 'REAL', 0, None, 0),
#  (355, 'jbintfam', 'REAL', 0, None, 0),
#  (356, 'jbtrain', 'REAL', 0, None, 0),
#  (357, 'jew', 'REAL', 0, None, 0),
#  (358, 'jew16', 'REAL', 0, None, 0),
#  (359, 'jobeasy', 'REAL', 0, None, 0),
#  (360, 'jobfind', 'REAL', 0, None, 0),
#  (361, 'joblose', 'REAL', 0, None, 0),
#  (362, 'joborfam', 'REAL', 0, None, 0),
#  (363, 'jobsall', 'REAL', 0, None, 0),
#  (364, 'jobsat', 'REAL', 0, None, 0),
#  (365, 'kidssol', 'REAL', 0, None, 0),
#  (366, 'lasers', 'REAL', 0, None, 0),
#  (367, 'leasthrs', 'REAL', 0, None, 0),
#  (368, 'leavejob', 'REAL', 0, None, 0),
#  (369, 'lessreg', 'REAL', 0, None, 0),
#  (370, 'letdie1', 'REAL', 0, None, 0),
#  (371, 'letin1', 'REAL', 0, None, 0),
#  (372, 'libath', 'REAL', 0, None, 0),
#  (373, 'libcom', 'REAL', 0, None, 0),
#  (374, 'libhomo', 'REAL', 0, None, 0),
#  (375, 'libmil', 'REAL', 0, None, 0),
#  (376, 'libmslm', 'REAL', 0, None, 0),
#  (377, 'librac', 'REAL', 0, None, 0),
#  (378, 'life', 'REAL', 0, None, 0),
#  (379, 'linkedin', 'REAL', 0, None, 0),
#  (380, 'liveblks', 'REAL', 0, None, 0),
#  (381, 'livewhts', 'REAL', 0, None, 0),
#  (382, 'lngthinv', 'INTEGER', 0, None, 0),
#  (383, 'localnum', 'REAL', 0, None, 0),
#  (384, 'lookjob', 'REAL', 0, None, 0),
#  (385, 'lotr1', 'REAL', 0, None, 0),
#  (386, 'lotr2', 'REAL', 0, None, 0),
#  (387, 'lotr3', 'REAL', 0, None, 0),
#  (388, 'lotr4', 'REAL', 0, None, 0),
#  (389, 'lotr5', 'REAL', 0, None, 0),
#  (390, 'lotr6', 'REAL', 0, None, 0),
#  (391, 'lowpay', 'REAL', 0, None, 0),
#  (392, 'madeg', 'REAL', 0, None, 0),
#  (393, 'maeduc', 'REAL', 0, None, 0),
#  (394, 'maind10', 'REAL', 0, None, 0),
#  (395, 'maisco08', 'REAL', 0, None, 0),
#  (396, 'maisco88', 'REAL', 0, None, 0),
#  (397, 'major1', 'REAL', 0, None, 0),
#  (398, 'major2', 'REAL', 0, None, 0),
#  (399, 'majorcol', 'REAL', 0, None, 0),
#  (400, 'makejobs', 'REAL', 0, None, 0),
#  (401, 'maocc10', 'REAL', 0, None, 0),
#  (402, 'mapres10', 'REAL', 0, None, 0),
#  (403, 'mapres105plus', 'REAL', 0, None, 0),
#  (404, 'marasian', 'REAL', 0, None, 0),
#  (405, 'marblk', 'REAL', 0, None, 0),
#  (406, 'marcohab', 'REAL', 0, None, 0),
#  (407, 'marhisp', 'REAL', 0, None, 0),
#  (408, 'marhomo', 'REAL', 0, None, 0),
#  (409, 'marital', 'REAL', 0, None, 0),
#  (410, 'martype', 'REAL', 0, None, 0),
#  (411, 'marwht', 'REAL', 0, None, 0),
#  (412, 'masei10', 'REAL', 0, None, 0),
#  (413, 'masei10educ', 'REAL', 0, None, 0),
#  (414, 'masei10inc', 'REAL', 0, None, 0),
#  (415, 'matesex', 'REAL', 0, None, 0),
#  (416, 'mawrkgrw', 'REAL', 0, None, 0),
#  (417, 'mawrkslf', 'REAL', 0, None, 0),
#  (418, 'meovrwrk', 'REAL', 0, None, 0),
#  (419, 'mntlhlth', 'REAL', 0, None, 0),
#  (420, 'mobile16', 'REAL', 0, None, 0),
#  (421, 'mode', 'REAL', 0, None, 0),
#  (422, 'mortravl', 'REAL', 0, None, 0),
#  (423, 'mosthrs', 'REAL', 0, None, 0),
#  (424, 'moveaway', 'REAL', 0, None, 0),
#  (425, 'moveinus', 'REAL', 0, None, 0),
#  (426, 'nanoben', 'REAL', 0, None, 0),
#  (427, 'nanoharm', 'REAL', 0, None, 0),
#  (428, 'nanowill', 'REAL', 0, None, 0),
#  (429, 'nataid', 'REAL', 0, None, 0),
#  (430, 'nataidy', 'REAL', 0, None, 0),
#  (431, 'natarms', 'REAL', 0, None, 0),
#  (432, 'natarmsy', 'REAL', 0, None, 0),
#  (433, 'natchld', 'REAL', 0, None, 0),
#  (434, 'natcity', 'REAL', 0, None, 0),
#  (435, 'natcityy', 'REAL', 0, None, 0),
#  (436, 'natcrime', 'REAL', 0, None, 0),
#  (437, 'natcrimy', 'REAL', 0, None, 0),
#  (438, 'natdrug', 'REAL', 0, None, 0),
#  (439, 'natdrugy', 'REAL', 0, None, 0),
#  (440, 'nateduc', 'REAL', 0, None, 0),
#  (441, 'nateducy', 'REAL', 0, None, 0),
#  (442, 'natenrgy', 'REAL', 0, None, 0),
#  (443, 'natenvir', 'REAL', 0, None, 0),
#  (444, 'natenviy', 'REAL', 0, None, 0),
#  (445, 'natfare', 'REAL', 0, None, 0),
#  (446, 'natfarey', 'REAL', 0, None, 0),
#  (447, 'natheal', 'REAL', 0, None, 0),
#  (448, 'nathealy', 'REAL', 0, None, 0),
#  (449, 'natmass', 'REAL', 0, None, 0),
#  (450, 'natpark', 'REAL', 0, None, 0),
#  (451, 'natrace', 'REAL', 0, None, 0),
#  (452, 'natracey', 'REAL', 0, None, 0),
#  (453, 'natroad', 'REAL', 0, None, 0),
#  (454, 'natsci', 'REAL', 0, None, 0),
#  (455, 'natsoc', 'REAL', 0, None, 0),
#  (456, 'natspac', 'REAL', 0, None, 0),
#  (457, 'natspacy', 'REAL', 0, None, 0),
#  (458, 'news', 'REAL', 0, None, 0),
#  (459, 'newsfrom', 'REAL', 0, None, 0),
#  (460, 'newskill', 'REAL', 0, None, 0),
#  (461, 'nextgen', 'REAL', 0, None, 0),
#  (462, 'nogo', 'REAL', 0, None, 0),
#  (463, 'nogo1', 'REAL', 0, None, 0),
#  (464, 'nounemp1', 'REAL', 0, None, 0),
#  (465, 'nounemp2', 'REAL', 0, None, 0),
#  (466, 'nounemp3', 'REAL', 0, None, 0),
#  (467, 'nounemp4', 'REAL', 0, None, 0),
#  (468, 'nounemp5', 'REAL', 0, None, 0),
#  (469, 'nounemp6', 'REAL', 0, None, 0),
#  (470, 'nukegen', 'REAL', 0, None, 0),
#  (471, 'numemps', 'REAL', 0, None, 0),
#  (472, 'nummen', 'REAL', 0, None, 0),
#  (473, 'numwomen', 'REAL', 0, None, 0),
#  (474, 'obey', 'REAL', 0, None, 0),
#  (475, 'obeylaw', 'REAL', 0, None, 0),
#  (476, 'occ10', 'REAL', 0, None, 0),
#  (477, 'odds1', 'REAL', 0, None, 0),
#  (478, 'odds2', 'REAL', 0, None, 0),
#  (479, 'old1', 'REAL', 0, None, 0),
#  (480, 'old10', 'REAL', 0, None, 0),
#  (481, 'old11', 'REAL', 0, None, 0),
#  (482, 'old12', 'REAL', 0, None, 0),
#  (483, 'old13', 'REAL', 0, None, 0),
#  (484, 'old14', 'REAL', 0, None, 0),
#  (485, 'old2', 'REAL', 0, None, 0),
#  (486, 'old3', 'REAL', 0, None, 0),
#  (487, 'old4', 'REAL', 0, None, 0),
#  (488, 'old5', 'REAL', 0, None, 0),
#  (489, 'old6', 'REAL', 0, None, 0),
#  (490, 'old7', 'REAL', 0, None, 0),
#  (491, 'old8', 'REAL', 0, None, 0),
#  (492, 'old9', 'REAL', 0, None, 0),
#  (493, 'oth16', 'REAL', 0, None, 0),
#  (494, 'other', 'REAL', 0, None, 0),
#  (495, 'othersex', 'REAL', 0, None, 0),
#  (496, 'othlang', 'REAL', 0, None, 0),
#  (497, 'othlang1', 'REAL', 0, None, 0),
#  (498, 'othlang2', 'REAL', 0, None, 0),
#  (499, 'oversamp', 'INTEGER', 0, None, 0),
#  (500, 'owngun', 'REAL', 0, None, 0),
#  (501, 'padeg', 'REAL', 0, None, 0),
#  (502, 'paeduc', 'REAL', 0, None, 0),
#  (503, 'paidhow', 'REAL', 0, None, 0),
#  (504, 'paidsex', 'REAL', 0, None, 0),
#  (505, 'paind10', 'REAL', 0, None, 0),
#  (506, 'paisco08', 'REAL', 0, None, 0),
#  (507, 'paisco88', 'REAL', 0, None, 0),
#  (508, 'paocc10', 'REAL', 0, None, 0),
#  (509, 'papres10', 'REAL', 0, None, 0),
#  (510, 'papres105plus', 'REAL', 0, None, 0),
#  (511, 'parborn', 'REAL', 0, None, 0),
#  (512, 'parsol', 'REAL', 0, None, 0),
#  (513, 'partfull', 'REAL', 0, None, 0),
#  (514, 'partners', 'REAL', 0, None, 0),
#  (515, 'partnrs5', 'REAL', 0, None, 0),
#  (516, 'partyid', 'REAL', 0, None, 0),
#  (517, 'pasei10', 'REAL', 0, None, 0),
#  (518, 'pasei10educ', 'REAL', 0, None, 0),
#  (519, 'pasei10inc', 'REAL', 0, None, 0),
#  (520, 'pawrkslf', 'REAL', 0, None, 0),
#  (521, 'phase', 'INTEGER', 0, None, 0),
#  (522, 'phone', 'INTEGER', 0, None, 0),
#  (523, 'pikupsex', 'REAL', 0, None, 0),
#  (524, 'pillok', 'REAL', 0, None, 0),
#  (525, 'pinterst', 'REAL', 0, None, 0),
#  (526, 'pistol', 'REAL', 0, None, 0),
#  (527, 'polabuse', 'REAL', 0, None, 0),
#  (528, 'polattak', 'REAL', 0, None, 0),
#  (529, 'poleff11', 'REAL', 0, None, 0),
#  (530, 'poleff13', 'REAL', 0, None, 0),
#  (531, 'poleff16', 'REAL', 0, None, 0),
#  (532, 'poleff17', 'REAL', 0, None, 0),
#  (533, 'polescap', 'REAL', 0, None, 0),
#  (534, 'polgbeco', 'REAL', 0, None, 0),
#  (535, 'polhitok', 'REAL', 0, None, 0),
#  (536, 'polint', 'REAL', 0, None, 0),
#  (537, 'polmurdr', 'REAL', 0, None, 0),
#  (538, 'polviews', 'REAL', 0, None, 0),
#  (539, 'popespks', 'REAL', 0, None, 0),
#  (540, 'popular', 'REAL', 0, None, 0),
#  (541, 'pornlaw', 'REAL', 0, None, 0),
#  (542, 'posslq', 'REAL', 0, None, 0),
#  (543, 'posslqy', 'REAL', 0, None, 0),
#  (544, 'postlife', 'REAL', 0, None, 0),
#  (545, 'pray', 'REAL', 0, None, 0),
#  (546, 'prayer', 'REAL', 0, None, 0),
#  (547, 'premarsx', 'REAL', 0, None, 0),
#  (548, 'pres12', 'REAL', 0, None, 0),
#  (549, 'prestg10', 'REAL', 0, None, 0),
#  (550, 'prestg105plus', 'REAL', 0, None, 0),
#  (551, 'preteen', 'REAL', 0, None, 0),
#  (552, 'prfmatt', 'REAL', 0, None, 0),
#  (553, 'prfmatt1', 'REAL', 0, None, 0),
#  (554, 'prfmatt2', 'REAL', 0, None, 0),
#  (555, 'prfmatt3', 'REAL', 0, None, 0),
#  (556, 'prfmatt4', 'REAL', 0, None, 0),
#  (557, 'prfmatt5', 'REAL', 0, None, 0),
#  (558, 'prfmcost', 'REAL', 0, None, 0),
#  (559, 'prfmdan', 'REAL', 0, None, 0),
#  (560, 'prfmfree', 'REAL', 0, None, 0),
#  (561, 'prfmgst', 'REAL', 0, None, 0),
#  (562, 'prfmint', 'REAL', 0, None, 0),
#  (563, 'prfmloc', 'REAL', 0, None, 0),
#  (564, 'prfmmostoth', 'REAL', 0, None, 0),
#  (565, 'prfmmus', 'REAL', 0, None, 0),
#  (566, 'prfmnce', 'REAL', 0, None, 0),
#  (567, 'prfmothr', 'REAL', 0, None, 0),
#  (568, 'prfmthe', 'REAL', 0, None, 0),
#  (569, 'prfmtime', 'REAL', 0, None, 0),
#  (570, 'prfmtrvl', 'REAL', 0, None, 0),
#  (571, 'prfmwhy0', 'REAL', 0, None, 0),
#  (572, 'prfmwhy1', 'REAL', 0, None, 0),
#  (573, 'prfmwhy2', 'REAL', 0, None, 0),
#  (574, 'prfmwhy3', 'REAL', 0, None, 0),
#  (575, 'prfmwhy4', 'REAL', 0, None, 0),
#  (576, 'prfmwhy5', 'REAL', 0, None, 0),
#  (577, 'prfmwhy6', 'REAL', 0, None, 0),
#  (578, 'prfmwhy7', 'REAL', 0, None, 0),
#  (579, 'prfmwhy8', 'REAL', 0, None, 0),
#  (580, 'prfmwhy9', 'REAL', 0, None, 0),
#  (581, 'priagncy', 'REAL', 0, None, 0),
#  (582, 'pricecon', 'REAL', 0, None, 0),
#  (583, 'prideorg', 'REAL', 0, None, 0),
#  (584, 'promotn', 'REAL', 0, None, 0),
#  (585, 'protest1', 'REAL', 0, None, 0),
#  (586, 'protest3', 'REAL', 0, None, 0),
#  (587, 'proudwrk', 'REAL', 0, None, 0),
#  (588, 'prvdhlth', 'REAL', 0, None, 0),
#  (589, 'prvdold', 'REAL', 0, None, 0),
#  (590, 'prvdschl', 'REAL', 0, None, 0),
#  (591, 'pubagncy', 'REAL', 0, None, 0),
#  (592, 'racdif1', 'REAL', 0, None, 0),
#  (593, 'racdif2', 'REAL', 0, None, 0),
#  (594, 'racdif3', 'REAL', 0, None, 0),
#  (595, 'racdif4', 'REAL', 0, None, 0),
#  (596, 'race', 'INTEGER', 0, None, 0),
#  (597, 'racecen1', 'REAL', 0, None, 0),
#  (598, 'racecen2', 'REAL', 0, None, 0),
#  (599, 'racecen3', 'REAL', 0, None, 0),
#  (600, 'racethas', 'REAL', 0, None, 0),
#  (601, 'racethbl', 'REAL', 0, None, 0),
#  (602, 'racethhi', 'REAL', 0, None, 0),
#  (603, 'racethna', 'REAL', 0, None, 0),
#  (604, 'racethot', 'REAL', 0, None, 0),
#  (605, 'racethwh', 'REAL', 0, None, 0),
#  (606, 'raclive', 'REAL', 0, None, 0),
#  (607, 'racopen', 'REAL', 0, None, 0),
#  (608, 'racwork', 'REAL', 0, None, 0),
#  (609, 'radioact', 'REAL', 0, None, 0),
#  (610, 'rank', 'REAL', 0, None, 0),
#  (611, 'ratetone', 'REAL', 0, None, 0),
#  (612, 'rcontact', 'REAL', 0, None, 0),
#  (613, 'realinc', 'REAL', 0, None, 0),
#  (614, 'realrinc', 'REAL', 0, None, 0),
#  (615, 'reborn', 'REAL', 0, None, 0),
#  (616, 'reg16', 'INTEGER', 0, None, 0),
#  (617, 'region', 'INTEGER', 0, None, 0),
#  (618, 'relactiv', 'REAL', 0, None, 0),
#  (619, 'relate1', 'INTEGER', 0, None, 0),
#  (620, 'relate10', 'REAL', 0, None, 0),
#  (621, 'relate11', 'REAL', 0, None, 0),
#  (622, 'relate12', 'REAL', 0, None, 0),
#  (623, 'relate13', 'REAL', 0, None, 0),
#  (624, 'relate14', 'REAL', 0, None, 0),
#  (625, 'relate2', 'REAL', 0, None, 0),
#  (626, 'relate3', 'REAL', 0, None, 0),
#  (627, 'relate4', 'REAL', 0, None, 0),
#  (628, 'relate5', 'REAL', 0, None, 0),
#  (629, 'relate6', 'REAL', 0, None, 0),
#  (630, 'relate7', 'REAL', 0, None, 0),
#  (631, 'relate8', 'REAL', 0, None, 0),
#  (632, 'relate9', 'REAL', 0, None, 0),
#  (633, 'relatsex', 'REAL', 0, None, 0),
#  (634, 'relhh1', 'INTEGER', 0, None, 0),
#  (635, 'relhh10', 'REAL', 0, None, 0),
#  (636, 'relhh11', 'REAL', 0, None, 0),
#  (637, 'relhh12', 'REAL', 0, None, 0),
#  (638, 'relhh13', 'REAL', 0, None, 0),
#  (639, 'relhh14', 'REAL', 0, None, 0),
#  (640, 'relhh2', 'REAL', 0, None, 0),
#  (641, 'relhh3', 'REAL', 0, None, 0),
#  (642, 'relhh4', 'REAL', 0, None, 0),
#  (643, 'relhh5', 'REAL', 0, None, 0),
#  (644, 'relhh6', 'REAL', 0, None, 0),
#  (645, 'relhh7', 'REAL', 0, None, 0),
#  (646, 'relhh8', 'REAL', 0, None, 0),
#  (647, 'relhh9', 'REAL', 0, None, 0),
#  (648, 'relhhd1', 'INTEGER', 0, None, 0),
#  (649, 'relhhd10', 'REAL', 0, None, 0),
#  (650, 'relhhd11', 'REAL', 0, None, 0),
#  (651, 'relhhd12', 'REAL', 0, None, 0),
#  (652, 'relhhd13', 'REAL', 0, None, 0),
#  (653, 'relhhd14', 'REAL', 0, None, 0),
#  (654, 'relhhd2', 'REAL', 0, None, 0),
#  (655, 'relhhd3', 'REAL', 0, None, 0),
#  (656, 'relhhd4', 'REAL', 0, None, 0),
#  (657, 'relhhd5', 'REAL', 0, None, 0),
#  (658, 'relhhd6', 'REAL', 0, None, 0),
#  (659, 'relhhd7', 'REAL', 0, None, 0),
#  (660, 'relhhd8', 'REAL', 0, None, 0),
#  (661, 'relhhd9', 'REAL', 0, None, 0),
#  (662, 'relig', 'REAL', 0, None, 0),
#  (663, 'relig16', 'REAL', 0, None, 0),
#  (664, 'reliten', 'REAL', 0, None, 0),
#  (665, 'relpersn', 'REAL', 0, None, 0),
#  (666, 'relsp1', 'REAL', 0, None, 0),
#  (667, 'relsp10', 'REAL', 0, None, 0),
#  (668, 'relsp11', 'REAL', 0, None, 0),
#  (669, 'relsp12', 'REAL', 0, None, 0),
#  (670, 'relsp2', 'REAL', 0, None, 0),
#  (671, 'relsp3', 'REAL', 0, None, 0),
#  (672, 'relsp4', 'REAL', 0, None, 0),
#  (673, 'relsp5', 'REAL', 0, None, 0),
#  (674, 'relsp6', 'REAL', 0, None, 0),
#  (675, 'relsp7', 'REAL', 0, None, 0),
#  (676, 'relsp8', 'REAL', 0, None, 0),
#  (677, 'relsp9', 'REAL', 0, None, 0),
#  (678, 'res16', 'REAL', 0, None, 0),
#  (679, 'respnum', 'REAL', 0, None, 0),
#  (680, 'revpub', 'REAL', 0, None, 0),
#  (681, 'revspeak', 'REAL', 0, None, 0),
#  (682, 'rhiinc', 'REAL', 0, None, 0),
#  (683, 'rhlpoths', 'REAL', 0, None, 0),
#  (684, 'rhlpsoc', 'REAL', 0, None, 0),
#  (685, 'richwork', 'REAL', 0, None, 0),
#  (686, 'rifle', 'REAL', 0, None, 0),
#  (687, 'rincom16', 'REAL', 0, None, 0),
#  (688, 'rincome', 'REAL', 0, None, 0),
#  (689, 'rintjob', 'REAL', 0, None, 0),
#  (690, 'rowngun', 'REAL', 0, None, 0),
#  (691, 'rplace', 'REAL', 0, None, 0),
#  (692, 'rpromotn', 'REAL', 0, None, 0),
#  (693, 'rsecjob', 'REAL', 0, None, 0),
#  (694, 'rushed', 'REAL', 0, None, 0),
#  (695, 'rvisitor', 'INTEGER', 0, None, 0),
#  (696, 'rwrkindp', 'REAL', 0, None, 0),
#  (697, 'sampcode', 'INTEGER', 0, None, 0),
#  (698, 'sample', 'INTEGER', 0, None, 0),
#  (699, 'satfin', 'REAL', 0, None, 0),
#  (700, 'satjob', 'REAL', 0, None, 0),
#  (701, 'savejobs', 'REAL', 0, None, 0),
#  (702, 'savesoul', 'REAL', 0, None, 0),
#  (703, 'scibnfts', 'REAL', 0, None, 0),
#  (704, 'scientbe', 'REAL', 0, None, 0),
#  (705, 'scientgo', 'REAL', 0, None, 0),
#  (706, 'scienthe', 'REAL', 0, None, 0),
#  (707, 'scientod', 'REAL', 0, None, 0),
#  (708, 'scifrom', 'REAL', 0, None, 0),
#  (709, 'scinews1', 'REAL', 0, None, 0),
#  (710, 'scinews2', 'REAL', 0, None, 0),
#  (711, 'scinews3', 'REAL', 0, None, 0),
#  (712, 'scistudy', 'REAL', 0, None, 0),
#  (713, 'scitext', 'REAL', 0, None, 0),
#  (714, 'secjob', 'REAL', 0, None, 0),
#  (715, 'seeksci', 'REAL', 0, None, 0),
#  (716, 'sei10', 'REAL', 0, None, 0),
#  (717, 'sei10educ', 'REAL', 0, None, 0),
#  (718, 'sei10inc', 'REAL', 0, None, 0),
#  (719, 'sethrs', 'REAL', 0, None, 0),
#  (720, 'sex', 'INTEGER', 0, None, 0),
#  (721, 'sexeduc', 'REAL', 0, None, 0),
#  (722, 'sexfreq', 'REAL', 0, None, 0),
#  (723, 'sexornt', 'REAL', 0, None, 0),
#  (724, 'sexsex', 'REAL', 0, None, 0),
#  (725, 'sexsex5', 'REAL', 0, None, 0),
#  (726, 'shotgun', 'REAL', 0, None, 0),
#  (727, 'sibs', 'REAL', 0, None, 0),
#  (728, 'size', 'INTEGER', 0, None, 0),
#  (729, 'skltrain', 'REAL', 0, None, 0),
#  (730, 'snapchat', 'REAL', 0, None, 0),
#  (731, 'snsmfrst', 'REAL', 0, None, 0),
#  (732, 'snsmnew', 'REAL', 0, None, 0),
#  (733, 'snsmot2a', 'REAL', 0, None, 0),
#  (734, 'snsmot2b', 'REAL', 0, None, 0),
#  (735, 'snsmot2c', 'REAL', 0, None, 0),
#  (736, 'snsmoth1', 'REAL', 0, None, 0),
#  (737, 'socbar', 'REAL', 0, None, 0),
#  (738, 'socfrend', 'REAL', 0, None, 0),
#  (739, 'socommun', 'REAL', 0, None, 0),
#  (740, 'socrel', 'REAL', 0, None, 0),
#  (741, 'solarrev', 'REAL', 0, None, 0),
#  (742, 'spaneng', 'INTEGER', 0, None, 0),
#  (743, 'spanint', 'REAL', 0, None, 0),
#  (744, 'spanking', 'REAL', 0, None, 0),
#  (745, 'spanself', 'REAL', 0, None, 0),
#  (746, 'sparms', 'REAL', 0, None, 0),
#  (747, 'sparts', 'REAL', 0, None, 0),
#  (748, 'spdeg', 'REAL', 0, None, 0),
#  (749, 'spden', 'REAL', 0, None, 0),
#  (750, 'spdipged', 'REAL', 0, None, 0),
#  (751, 'speduc', 'REAL', 0, None, 0),
#  (752, 'spenviro', 'REAL', 0, None, 0),
#  (753, 'spevwork', 'REAL', 0, None, 0),
#  (754, 'spfund', 'REAL', 0, None, 0),
#  (755, 'sphlth', 'REAL', 0, None, 0),
#  (756, 'sphrs1', 'REAL', 0, None, 0),
#  (757, 'sphrs2', 'REAL', 0, None, 0),
#  (758, 'spind10', 'REAL', 0, None, 0),
#  (759, 'spisco08', 'REAL', 0, None, 0),
#  (760, 'spisco88', 'REAL', 0, None, 0),
#  (761, 'spjew', 'REAL', 0, None, 0),
#  (762, 'spjewaj', 'INTEGER', 0, None, 0),
#  (763, 'spkath', 'REAL', 0, None, 0),
#  (764, 'spkcom', 'REAL', 0, None, 0),
#  (765, 'spkhomo', 'REAL', 0, None, 0),
#  (766, 'spklang', 'REAL', 0, None, 0),
#  (767, 'spkmil', 'REAL', 0, None, 0),
#  (768, 'spkmslm', 'REAL', 0, None, 0),
#  (769, 'spkrac', 'REAL', 0, None, 0),
#  (770, 'spocc10', 'REAL', 0, None, 0),
#  (771, 'spother', 'REAL', 0, None, 0),
#  (772, 'sppolice', 'REAL', 0, None, 0),
#  (773, 'sppres10', 'REAL', 0, None, 0),
#  (774, 'sppres105plus', 'REAL', 0, None, 0),
#  (775, 'sprel', 'REAL', 0, None, 0),
#  (776, 'spretire', 'REAL', 0, None, 0),
#  (777, 'sprtprsn', 'REAL', 0, None, 0),
#  (778, 'spschool', 'REAL', 0, None, 0),
#  (779, 'spsei10', 'REAL', 0, None, 0),
#  (780, 'spsei10educ', 'REAL', 0, None, 0),
#  (781, 'spsei10inc', 'REAL', 0, None, 0),
#  (782, 'spunemp', 'REAL', 0, None, 0),
#  (783, 'spwrkslf', 'REAL', 0, None, 0),
#  (784, 'spwrksta', 'REAL', 0, None, 0),
#  (785, 'srcbelt', 'INTEGER', 0, None, 0),
#  (786, 'stayorg3', 'REAL', 0, None, 0),
#  (787, 'stoprndm', 'REAL', 0, None, 0),
#  (788, 'stress', 'REAL', 0, None, 0),
#  (789, 'stresswk', 'REAL', 0, None, 0),
#  (790, 'strngun', 'REAL', 0, None, 0),
#  (791, 'suicide1', 'REAL', 0, None, 0),
#  (792, 'suicide2', 'REAL', 0, None, 0),
#  (793, 'suicide3', 'REAL', 0, None, 0),
#  (794, 'suicide4', 'REAL', 0, None, 0),
#  (795, 'suiclse1', 'REAL', 0, None, 0),
#  (796, 'suiclse2', 'REAL', 0, None, 0),
#  (797, 'suimths1', 'REAL', 0, None, 0),
#  (798, 'suimths2', 'REAL', 0, None, 0),
#  (799, 'suineg1', 'REAL', 0, None, 0),
#  (800, 'suineg2', 'REAL', 0, None, 0),
#  (801, 'suinum', 'REAL', 0, None, 0),
#  (802, 'suinum1', 'REAL', 0, None, 0),
#  (803, 'suirel1', 'REAL', 0, None, 0),
#  (804, 'suirel2', 'REAL', 0, None, 0),
#  (805, 'suitime1', 'REAL', 0, None, 0),
#  (806, 'suitime2', 'REAL', 0, None, 0),
#  (807, 'suiyrs1', 'REAL', 0, None, 0),
#  (808, 'suiyrs2', 'REAL', 0, None, 0),
#  (809, 'supervis', 'INTEGER', 0, None, 0),
#  (810, 'tapphone', 'REAL', 0, None, 0),
#  (811, 'tax', 'REAL', 0, None, 0),
#  (812, 'taxbylaw', 'REAL', 0, None, 0),
#  (813, 'taxmid', 'REAL', 0, None, 0),
#  (814, 'taxpaid', 'REAL', 0, None, 0),
#  (815, 'taxpoor', 'REAL', 0, None, 0),
#  (816, 'taxrich', 'REAL', 0, None, 0),
#  (817, 'teens', 'REAL', 0, None, 0),
#  (818, 'teensex', 'REAL', 0, None, 0),
#  (819, 'tempgen', 'REAL', 0, None, 0),
#  (820, 'tempwork', 'REAL', 0, None, 0),
#  (821, 'thnkself', 'REAL', 0, None, 0),
#  (822, 'timeoff', 'REAL', 0, None, 0),
#  (823, 'toofast', 'REAL', 0, None, 0),
#  (824, 'trust', 'REAL', 0, None, 0),
#  (825, 'tumblr', 'REAL', 0, None, 0),
#  (826, 'tvhours', 'REAL', 0, None, 0),
#  (827, 'twitter', 'REAL', 0, None, 0),
#  (828, 'unemp', 'REAL', 0, None, 0),
#  (829, 'union', 'REAL', 0, None, 0),
#  (830, 'union1', 'REAL', 0, None, 0),
#  (831, 'unionsbd', 'REAL', 0, None, 0),
#  (832, 'unrelat', 'REAL', 0, None, 0),
#  (833, 'uscitzn', 'REAL', 0, None, 0),
#  (834, 'useskill', 'REAL', 0, None, 0),
#  (835, 'usewww', 'REAL', 0, None, 0),
#  (836, 'usualhrs', 'REAL', 0, None, 0),
#  (837, 'uswar', 'REAL', 0, None, 0),
#  (838, 'uswary', 'REAL', 0, None, 0),
#  (839, 'verdict', 'REAL', 0, None, 0),
#  (840, 'version', 'INTEGER', 0, None, 0),
#  (841, 'vetyears', 'REAL', 0, None, 0),
#  (842, 'vine', 'REAL', 0, None, 0),
#  (843, 'viruses', 'REAL', 0, None, 0),
#  (844, 'visitors', 'INTEGER', 0, None, 0),
#  (845, 'visnhist', 'REAL', 0, None, 0),
#  (846, 'vissci', 'REAL', 0, None, 0),
#  (847, 'viszoo', 'REAL', 0, None, 0),
#  (848, 'voedcol', 'REAL', 0, None, 0),
#  (849, 'voedncol', 'REAL', 0, None, 0),
#  (850, 'voednme1', 'REAL', 0, None, 0),
#  (851, 'voednme2', 'REAL', 0, None, 0),
#  (852, 'vote12', 'REAL', 0, None, 0),
#  (853, 'vpsu', 'INTEGER', 0, None, 0),
#  (854, 'vstrat', 'INTEGER', 0, None, 0),
#  (855, 'wantads', 'REAL', 0, None, 0),
#  (856, 'wantjob1', 'REAL', 0, None, 0),
#  (857, 'wantjob2', 'REAL', 0, None, 0),
#  (858, 'watergen', 'REAL', 0, None, 0),
#  (859, 'webmob', 'REAL', 0, None, 0),
#  (860, 'weekswrk', 'REAL', 0, None, 0),
#  (861, 'whatsapp', 'REAL', 0, None, 0),
#  (862, 'whencol', 'REAL', 0, None, 0),
#  (863, 'whenhs', 'REAL', 0, None, 0),
#  (864, 'where1', 'REAL', 0, None, 0),
#  (865, 'where11', 'REAL', 0, None, 0),
#  (866, 'where13', 'REAL', 0, None, 0),
#  (867, 'where2', 'REAL', 0, None, 0),
#  (868, 'where3', 'REAL', 0, None, 0),
#  (869, 'where4', 'REAL', 0, None, 0),
#  (870, 'where5', 'REAL', 0, None, 0),
#  (871, 'where7', 'REAL', 0, None, 0),
#  (872, 'whoelse1', 'REAL', 0, None, 0),
#  (873, 'whoelse2', 'REAL', 0, None, 0),
#  (874, 'whoelse3', 'REAL', 0, None, 0),
#  (875, 'whoelse4', 'REAL', 0, None, 0),
#  (876, 'whoelse5', 'REAL', 0, None, 0),
#  (877, 'whoelse6', 'REAL', 0, None, 0),
#  (878, 'whydisc5', 'REAL', 0, None, 0),
#  (879, 'whyjbend', 'REAL', 0, None, 0),
#  (880, 'widowed', 'REAL', 0, None, 0),
#  (881, 'wkathome', 'REAL', 0, None, 0),
#  (882, 'wkpersnl', 'REAL', 0, None, 0),
#  (883, 'wksub', 'REAL', 0, None, 0),
#  (884, 'wksub1', 'REAL', 0, None, 0),
#  (885, 'wksubs', 'REAL', 0, None, 0),
#  (886, 'wksubs1', 'REAL', 0, None, 0),
#  (887, 'wksup', 'REAL', 0, None, 0),
#  (888, 'wksup1', 'REAL', 0, None, 0),
#  (889, 'wksups', 'REAL', 0, None, 0),
#  (890, 'wksups1', 'REAL', 0, None, 0),
#  (891, 'wkwkends', 'REAL', 0, None, 0),
#  (892, 'wlthblks', 'REAL', 0, None, 0),
#  (893, 'wlthwhts', 'REAL', 0, None, 0),
#  (894, 'worda', 'REAL', 0, None, 0),
#  (895, 'wordb', 'REAL', 0, None, 0),
#  (896, 'wordc', 'REAL', 0, None, 0),
#  (897, 'wordd', 'REAL', 0, None, 0),
#  (898, 'worde', 'REAL', 0, None, 0),
#  (899, 'wordf', 'REAL', 0, None, 0),
#  (900, 'wordg', 'REAL', 0, None, 0),
#  (901, 'wordh', 'REAL', 0, None, 0),
#  (902, 'wordi', 'REAL', 0, None, 0),
#  (903, 'wordj', 'REAL', 0, None, 0),
#  (904, 'wordsum', 'REAL', 0, None, 0),
#  (905, 'worecsup', 'REAL', 0, None, 0),
#  (906, 'workblks', 'REAL', 0, None, 0),
#  (907, 'workhard', 'REAL', 0, None, 0),
#  (908, 'worknow', 'REAL', 0, None, 0),
#  (909, 'workwhts', 'REAL', 0, None, 0),
#  (910, 'wornojob', 'REAL', 0, None, 0),
#  (911, 'worryjob', 'REAL', 0, None, 0),
#  (912, 'wotrial', 'REAL', 0, None, 0),
#  (913, 'wrkearn', 'REAL', 0, None, 0),
#  (914, 'wrkenjoy', 'REAL', 0, None, 0),
#  (915, 'wrkgovt', 'REAL', 0, None, 0),
#  (916, 'wrkindp', 'REAL', 0, None, 0),
#  (917, 'wrkshift', 'REAL', 0, None, 0),
#  (918, 'wrkslf', 'REAL', 0, None, 0),
#  (919, 'wrkstat', 'REAL', 0, None, 0),
#  (920, 'wrkwayup', 'REAL', 0, None, 0),
#  (921, 'wtss', 'REAL', 0, None, 0),
#  (922, 'wtssall', 'REAL', 0, None, 0),
#  (923, 'wtssnr', 'REAL', 0, None, 0),
#  (924, 'wwwhr', 'REAL', 0, None, 0),
#  (925, 'wwwmin', 'REAL', 0, None, 0),
#  (926, 'xhaustn', 'REAL', 0, None, 0),
#  (927, 'xmarsex', 'REAL', 0, None, 0),
#  (928, 'xmovie', 'REAL', 0, None, 0),
#  (929, 'xnorcsiz', 'INTEGER', 0, None, 0),
#  (930, 'year', 'INTEGER', 0, None, 0),
#  (931, 'zodiac', 'REAL', 0, None, 0),
#  (932, 'intstart', 'REAL', 0, None, 0),
#  (933, 'snsmyear', 'REAL', 0, None, 0),
#  (934, 'hlthstrt', 'REAL', 0, None, 0),
#  (935, 'huadd', 'REAL', 0, None, 0),
#  (936, 'huaddwhy', 'REAL', 0, None, 0),
#  (937, 'dwellpre', 'REAL', 0, None, 0),
#  (938, 'kidsinhh', 'REAL', 0, None, 0),
#  (939, 'respond', 'REAL', 0, None, 0),
#  (940, 'incuspop', 'REAL', 0, None, 0),
#  (941, 'neisafe', 'REAL', 0, None, 0),
#  (942, 'rlooks', 'REAL', 0, None, 0),
#  (943, 'rgroomed', 'REAL', 0, None, 0),
#  (944, 'rweight', 'REAL', 0, None, 0),
#  (945, 'rhlthend', 'REAL', 0, None, 0),
#  (946, 'prfmothr1', 'REAL', 0, None, 0),
#  (947, 'satjobhv', 'REAL', 0, None, 0),
#  (948, 'racethmn', 'REAL', 0, None, 0),
#  (949, 'sector', 'REAL', 0, None, 0),
#  (950, 'eftotlt', 'REAL', 0, None, 0),
#  (951, 'barate', 'REAL', 0, None, 0),
#  (952, 'gradtounder', 'REAL', 0, None, 0),
#  (953, 'spsector', 'REAL', 0, None, 0),
#  (954, 'speftotlt', 'REAL', 0, None, 0),
#  (955, 'spbarate', 'REAL', 0, None, 0),
#  (956, 'spgradtounder', 'REAL', 0, None, 0),
#  (957, 'cosector', 'REAL', 0, None, 0),
#  (958, 'coeftotlt', 'REAL', 0, None, 0),
#  (959, 'cobarate', 'REAL', 0, None, 0),
#  (960, 'cogradtounder', 'REAL', 0, None, 0)]

# %%
sql_2016 = c.execute("SELECT educ, income16 FROM year_2016;")

# %%
sql_2016.fetchone()
# Out:
# (16.0, 26.0)

# %%
sql_2016.fetchall()
# Out:
# [(12.0, 19.0),
#  (16.0, 21.0),
#  (12.0, 26.0),
#  (18.0, 26.0),
#  (14.0, 20.0),
#  (14.0, 26.0),
#  (11.0, 16.0),
#  (12.0, 20.0),
#  (14.0, 20.0),
#  (12.0, 1.0),
#  (12.0, 1.0),
#  (12.0, 8.0),
#  (None, 10.0),
#  (10.0, 18.0),
#  (13.0, 19.0),
#  (13.0, 19.0),
#  (10.0, 5.0),
#  (18.0, 17.0),
#  (13.0, 15.0),
#  (12.0, 22.0),
#  (11.0, 18.0),
#  (10.0, 14.0),
#  (12.0, 20.0),
#  (15.0, 13.0),
#  (3.0, 5.0),
#  (19.0, None),
#  (14.0, None),
#  (18.0, 23.0),
#  (12.0, 16.0),
#  (12.0, 17.0),
#  (12.0, 20.0),
#  (12.0, 25.0),
#  (14.0, 21.0),
#  (12.0, 18.0),
#  (12.0, 22.0),
#  (16.0, 21.0),
#  (16.0, 23.0),
#  (16.0, 23.0),
#  (14.0, 16.0),
#  (12.0, 18.0),
#  (12.0, 17.0),
#  (16.0, 22.0),
#  (20.0, 16.0),
#  (17.0, 10.0),
#  (15.0, 21.0),
#  (16.0, None),
#  (16.0, 19.0),
#  (17.0, 16.0),
#  (16.0, 23.0),
#  (16.0, 24.0),
#  (12.0, 21.0),
#  (13.0, None),
#  (19.0, 26.0),
#  (16.0, None),
#  (16.0, 25.0),
#  (17.0, 21.0),
#  (17.0, 20.0),
#  (20.0, 8.0),
#  (10.0, 10.0),
#  (13.0, 13.0),
#  (12.0, 1.0),
#  (12.0, 8.0),
#  (13.0, 15.0),
#  (11.0, 2.0),
#  (10.0, 16.0),
#  (12.0, 14.0),
#  (10.0, 1.0),
#  (11.0, None),
#  (6.0, 12.0),
#  (10.0, 10.0),
#  (14.0, 22.0),
#  (11.0, 19.0),
#  (12.0, 14.0),
#  (18.0, 21.0),
#  (10.0, None),
#  (20.0, 19.0),
#  (18.0, 20.0),
#  (19.0, 26.0),
#  (12.0, None),
#  (14.0, 26.0),
#  (14.0, 20.0),
#  (16.0, 25.0),
#  (12.0, 25.0),
#  (16.0, 23.0),
#  (12.0, 26.0),
#  (12.0, 17.0),
#  (14.0, 20.0),
#  (12.0, 18.0),
#  (13.0, 5.0),
#  (20.0, 26.0),
#  (12.0, 14.0),
#  (11.0, 18.0),
#  (9.0, 6.0),
#  (12.0, 19.0),
#  (9.0, 7.0),
#  (13.0, 19.0),
#  (12.0, 15.0),
#  (17.0, 22.0),
#  (18.0, 18.0),
#  (17.0, 16.0),
#  (17.0, 19.0),
#  (14.0, None),
#  (16.0, 24.0),
#  (16.0, 23.0),
#  (13.0, 2.0),
#  (10.0, 9.0),
#  (12.0, 3.0),
#  (14.0, 17.0),
#  (14.0, None),
#  (8.0, 2.0),
#  (13.0, 17.0),
#  (12.0, 2.0),
#  (16.0, None),
#  (14.0, 18.0),
#  (12.0, 14.0),
#  (12.0, None),
#  (12.0, 11.0),
#  (12.0, 1.0),
#  (12.0, 8.0),
#  (12.0, 8.0),
#  (12.0, None),
#  (12.0, 15.0),
#  (12.0, 23.0),
#  (12.0, 11.0),
#  (12.0, 18.0),
#  (12.0, 9.0),
#  (16.0, None),
#  (15.0, 15.0),
#  (16.0, 23.0),
#  (14.0, 12.0),
#  (15.0, None),
#  (10.0, 1.0),
#  (12.0, None),
#  (19.0, None),
#  (13.0, None),
#  (14.0, 19.0),
#  (12.0, 14.0),
#  (16.0, 9.0),
#  (12.0, None),
#  (12.0, 24.0),
#  (14.0, 11.0),
#  (19.0, 26.0),
#  (16.0, 18.0),
#  (12.0, 14.0),
#  (13.0, 25.0),
#  (13.0, 21.0),
#  (16.0, 10.0),
#  (14.0, 18.0),
#  (12.0, 19.0),
#  (12.0, None),
#  (6.0, None),
#  (11.0, 11.0),
#  (12.0, 22.0),
#  (12.0, 19.0),
#  (16.0, 24.0),
#  (17.0, None),
#  (17.0, 24.0),
#  (12.0, 12.0),
#  (8.0, 21.0),
#  (12.0, 17.0),
#  (14.0, 20.0),
#  ...]

# %%
year_2016_df = pd.read_sql_query("SELECT educ, income16 FROM year_2016;", conn)

# %%
year_2016_df
# Out:
#       educ  income16
# 0     16.0      26.0
# 1     12.0      19.0
# 2     16.0      21.0
# 3     12.0      26.0
# 4     18.0      26.0
# 5     14.0      20.0
# 6     14.0      26.0
# 7     11.0      16.0
# 8     12.0      20.0
# 9     14.0      20.0
# 10    12.0       1.0
# 11    12.0       1.0
# 12    12.0       8.0
# 13     NaN      10.0
# 14    10.0      18.0
# 15    13.0      19.0
# 16    13.0      19.0
# 17    10.0       5.0
# 18    18.0      17.0
# 19    13.0      15.0
# 20    12.0      22.0
# 21    11.0      18.0
# 22    10.0      14.0
# 23    12.0      20.0
# 24    15.0      13.0
# 25     3.0       5.0
# 26    19.0       NaN
# 27    14.0       NaN
# 28    18.0      23.0
# 29    12.0      16.0
# ...    ...       ...
# 2837  11.0      24.0
# 2838  16.0      20.0
# 2839  16.0      22.0
# 2840  16.0      22.0
# 2841  18.0      18.0
# 2842  14.0      21.0
# 2843  14.0      21.0
# 2844  14.0      13.0
# 2845  12.0      19.0
# 2846   7.0      13.0
# 2847  14.0      20.0
# 2848  17.0      21.0
# 2849  12.0      20.0
# 2850  14.0      22.0
# 2851  12.0      22.0
# 2852  12.0      24.0
# 2853  16.0      19.0
# 2854  11.0      21.0
# 2855  15.0       3.0
# 2856  15.0      21.0
# 2857  12.0      15.0
# 2858  15.0      19.0
# 2859  12.0       6.0
# 2860  13.0      19.0
# 2861  12.0       9.0
# 2862  20.0      23.0
# 2863  15.0      17.0
# 2864  14.0      19.0
# 2865  14.0      15.0
# 2866  16.0      21.0
#
# [2867 rows x 2 columns]

# %%
c.close()
conn.commit()
conn.close()

# %%
conn = sqlite3.connect('manual.db')
c = conn.cursor()

# %%
table_name1 = 'my_table_1'  # name of the table to be created
table_name2 = 'my_table_2'  # name of the table to be created
new_field = 'my_1st_column' # name of the column
field_type = 'INTEGER'  # column data type

# %%
c.execute('CREATE TABLE {tn} ({nf} {ft})'\
        .format(tn=table_name1, nf=new_field, ft=field_type))

# %%
c.execute('CREATE TABLE {tn} ({nf} {ft} PRIMARY KEY)'\
        .format(tn=table_name2, nf=new_field, ft=field_type))

# %%
conn.commit()
conn.close()

# %%
conn = sqlite3.connect('manual.db')
c = conn.cursor()

# %%
c.execute("SELECT name FROM sqlite_master WHERE type='table';").fetchall()
# Out:
# [('my_table_1',), ('my_table_2',)]

# %%
table_name = 'my_table_2'   # name of the table to be created
id_column = 'my_1st_column' # name of the PRIMARY KEY column
new_column1 = 'my_2nd_column'  # name of the new column
new_column2 = 'my_3nd_column'  # name of the new column
column_type = 'TEXT' # E.g., INTEGER, TEXT, NULL, REAL, BLOB
default_val = 'Hello World' # a default value for the new column rows

# A) Adding a new column without a row value
c.execute("ALTER TABLE {tn} ADD COLUMN '{cn}' {ct}"\
        .format(tn=table_name, cn=new_column1, ct=column_type))

# %%
c.execute("ALTER TABLE {tn} ADD COLUMN '{cn}' {ct} DEFAULT '{df}'"\
        .format(tn=table_name, cn=new_column2, ct=column_type, df=default_val))

# %%
c.execute('PRAGMA table_info({tn})'.format(tn = table_name)).fetchall()
# Out:
# [(0, 'my_1st_column', 'INTEGER', 0, None, 1),
#  (1, 'my_2nd_column', 'TEXT', 0, None, 0),
#  (2, 'my_3nd_column', 'TEXT', 0, "'Hello World'", 0)]

# %%
conn.commit()
conn.close()

# %%
sqlite_file = 'my_first_db.sqlite'
table_name = 'my_table_2'
id_column = 'my_1st_column'
column_name = 'my_2nd_column'

# Connecting to the database file
conn = sqlite3.connect('manual.db')
c = conn.cursor()

# A) Inserts an ID with a specific value in a second column
try:
    c.execute("INSERT INTO {tn} ({idf}, {cn}) VALUES (123456, 'test')".\
        format(tn=table_name, idf=id_column, cn=column_name))
except sqlite3.IntegrityError:
    print('ERROR: ID already exists in PRIMARY KEY column {}'.format(id_column))

# B) Tries to insert an ID (if it does not exist yet)
# with a specific value in a second column
c.execute("INSERT OR IGNORE INTO {tn} ({idf}, {cn}) VALUES (123456, 'test')".\
        format(tn=table_name, idf=id_column, cn=column_name))

# C) Updates the newly inserted or pre-existing entry            
c.execute("UPDATE {tn} SET {cn}=('Hi World') WHERE {idf}=(123456)".\
        format(tn=table_name, cn=column_name, idf=id_column))

# %%
c.execute('SELECT * FROM {tn}'.format(tn = table_name)).fetchall()
# Out:
# [(123456, 'Hi World', 'Hello World')]

# %%
conn.commit()
conn.close()

# %%
sqlite_file = 'my_first_db.sqlite'    # name of the sqlite database file
table_name = 'my_table_2'   # name of the table to be created
id_column = 'my_1st_column' # name of the PRIMARY KEY column
new_column = 'unique_names'  # name of the new column
column_type = 'TEXT' # E.g., INTEGER, TEXT, NULL, REAL, BLOB
index_name = 'my_unique_index'  # name for the new unique index

# Connecting to the database file
conn = sqlite3.connect('manual.db')
c = conn.cursor()

# Adding a new column and update some record
c.execute("ALTER TABLE {tn} ADD COLUMN '{cn}' {ct}"\
        .format(tn=table_name, cn=new_column, ct=column_type))
c.execute("UPDATE {tn} SET {cn}='sebastian_r' WHERE {idf}=123456".\
        format(tn=table_name, idf=id_column, cn=new_column))

# Creating an unique index
c.execute('CREATE INDEX {ix} on {tn}({cn})'\
        .format(ix=index_name, tn=table_name, cn=new_column))

# Dropping the unique index
# E.g., to avoid future conflicts with update/insert functions
c.execute('DROP INDEX {ix}'.format(ix=index_name))

# %%
conn.commit()
conn.close()

# %%
sqlite_file = 'my_first_db.sqlite'    # name of the sqlite database file
table_name = 'my_table_2'   # name of the table to be queried
id_column = 'my_1st_column'
some_id = 123456
column_2 = 'my_2nd_column'

# Connecting to the database file
conn = sqlite3.connect('manual.db')
c = conn.cursor()

# 1) Contents of all columns for row that match a certain value in 1 column
c.execute('SELECT * FROM {tn} WHERE {cn}="Hi World"'.\
        format(tn=table_name, cn=column_2))
all_rows = c.fetchall()
print('1):', all_rows)

# 2) Value of a particular column for rows that match a certain value in column_1
c.execute('SELECT ({coi}) FROM {tn} WHERE {cn}="Hi World"'.\
        format(coi=column_2, tn=table_name, cn=column_2))
all_rows = c.fetchall()
print('2):', all_rows)

# 3) Value of 2 particular columns for rows that match a certain value in 1 column
c.execute('SELECT {coi1} FROM {tn} WHERE {coi1}="Hi World"'.\
        format(coi1=column_2, tn=table_name, cn=column_2))
all_rows = c.fetchall()
print('3):', all_rows)

# 4) Selecting only up to 10 rows that match a certain value in 1 column
c.execute('SELECT * FROM {tn} WHERE {cn}="Hi World" LIMIT 10'.\
        format(tn=table_name, cn=column_2))
ten_rows = c.fetchall()
print('4):', ten_rows)

# 5) Check if a certain ID exists and print its column contents
c.execute("SELECT * FROM {tn} WHERE {idf}={my_id}".\
        format(tn=table_name, cn=column_2, idf=id_column, my_id=some_id))
id_exists = c.fetchone()
if id_exists:
    print('5): {}'.format(id_exists))
else:
    print('5): {} does not exist'.format(some_id))

# Closing the connection to the database file
conn.close()
# Out:
# 1): [(123456, 'Hi World', 'Hello World', 'sebastian_r')]
# 2): [('Hi World',)]
# 3): [('Hi World',)]
# 4): [(123456, 'Hi World', 'Hello World', 'sebastian_r')]
# 5): (123456, 'Hi World', 'Hello World', 'sebastian_r')
